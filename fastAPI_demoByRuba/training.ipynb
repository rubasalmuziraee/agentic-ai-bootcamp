# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

import pickle
# Out:
# /Users/schen/.pyenv/versions/3.7.8/envs/wecloud378/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
iris_dataset = load_iris()
 
# split 80/20 train-test
X_train, X_test, y_train, y_test = train_test_split(iris_dataset.data,
                                                    iris_dataset.target,
                                                    test_size=0.2)

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
# Out:
# /Users/schen/.pyenv/versions/3.7.8/envs/wecloud378/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
# predict on one sample from the test set
clf.predict(X_test[0].reshape(1, -1))
# Out:
# array([2])

# %%
# predict on entire test set
predictions = clf.predict(X_test)

# %%
# calculate accuracy
accuracy_score(y_test, predictions)
# Out:
# 0.8333333333333334

# %%
#save model
print(clf)
# Out:
# LogisticRegression(random_state=0)

# %%
model_object = 'models/iris_model.pickle'
with open(model_object, 'wb') as file:
  pickle.dump(clf, file)

# %%
model_object = 'models/iris_model.pickle'
with open(model_object, 'rb') as file:
  loaded_model = pickle.load(file)

# %%
# predict on entire test set
predictions = loaded_model.predict(X_test)

# %%
# calculate accuracy
accuracy_score(y_test, predictions)
# Out:
# 0.8333333333333334

# %%
features = list(map(lambda x: x.replace(" (cm)", "").replace(" ", "_"), iris_dataset.feature_names))
print(features)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
feature_names = 'models/iris_features.pickle'
with open(feature_names, 'wb') as file:
  pickle.dump(features, file)

# %%
feature_names = 'models/iris_features.pickle'
with open(feature_names, 'rb') as file:
  loaded_features = pickle.load(file)

# %%
loaded_features
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
